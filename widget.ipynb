# %% [markdown]
# # Q1

# %%
import json
with open('/Users/dgy/Downloads/Hylink/widget_data.json', 'r') as f:
    data = json.load(f)

# %%
data
# Out:
# {'limits': {'V1': [3, 4],
#   'V2': [8, 9],
#   'V3': [4, 5],
#   'V4': [7, 8],
#   'V5': [15, 16]},
#  'machine_1': {'V1': [3.4522436410000004,
#    3.9569147260000004,
#    3.6608729419999997,
#    3.4529987139999996,
#    3.1495664389999996,
#    4.182149121,
#    2.829184451,
#    3.599506789,
#    3.60555917,
#    3.105323475,
#    3.867720422,
#    3.7190657,
#    3.541227604,
#    3.289805892,
#    3.300241344,
#    3.70121185,
#    2.8610957360000002,
#    3.441008987,
#    3.0543986000000003,
#    3.8110620689999997,
#    3.5275249989999997,
#    3.645588835,
#    3.3441805610000004,
#    3.829906334,
#    3.283065656,
#    3.75452599,
#    3.3960398339999998,
#    3.300396665,
#    4.0609833360000005,
#    3.401843992,
#    3.943549708,
#    3.3844383469999997,
#    3.640007427,
#    4.021114174,
#    3.42414435,
#    3.799018699,
#    3.454601382,
#    3.663013573,
#    3.70491871,
#    3.643371015,
#    3.723738369,
#    3.497688957,
#    3.571993243,
#    3.185041786,
# ...

# %%
limits = data['limits']
limits_V1 = limits['V1']
limits_V2 = limits['V2']
limits_V3 = limits['V3']
limits_V4 = limits['V4']
limits_V5 = limits['V5']

# %%
m1 = data['machine_1']
m2 = data['machine_2']
m3 = data['machine_3']

# %%
m1_V1 = m1['V1']
res_m1_V1 = [0] * 100
for i in range(len(m1_V1)):
    if limits_V1[0] <= m1_V1[i] <= limits_V1[1]:
        res_m1_V1[i] = 1

m1_V2 = m1['V2']
res_m1_V2 = [0] * 100
for i in range(len(m1_V1)):
    if limits_V2[0] <= m1_V2[i] <= limits_V2[1]:
        res_m1_V2[i] = 1

m1_V3 = m1['V3']
res_m1_V3 = [0] * 100
for i in range(len(m1_V3)):
    if limits_V3[0] <= m1_V3[i] <= limits_V3[1]:
        res_m1_V3[i] = 1
        
m1_V4 = m1['V4']
res_m1_V4 = [0] * 100
for i in range(len(m1_V4)):
    if limits_V4[0] <= m1_V4[i] <= limits_V4[1]:
        res_m1_V4[i] = 1
        
m1_V5 = m1['V5']
res_m1_V5 = [0] * 100
for i in range(len(m1_V1)):
    if limits_V5[0] <= m1_V5[i] <= limits_V5[1]:
        res_m1_V5[i] = 1

# %%
m2_V1 = m2['V1']
res_m2_V1 = [0] * 100
for i in range(len(m2_V1)):
    if limits_V1[0] <= m2_V1[i] <= limits_V1[1]:
        res_m2_V1[i] = 1

m2_V2 = m2['V2']
res_m2_V2 = [0] * 100
for i in range(len(m2_V1)):
    if limits_V2[0] <= m2_V2[i] <= limits_V2[1]:
        res_m2_V2[i] = 1

m2_V3 = m2['V3']
res_m2_V3 = [0] * 100
for i in range(len(m2_V3)):
    if limits_V3[0] <= m2_V3[i] <= limits_V3[1]:
        res_m2_V3[i] = 1
        
m2_V4 = m2['V4']
res_m2_V4 = [0] * 100
for i in range(len(m2_V4)):
    if limits_V4[0] <= m2_V4[i] <= limits_V4[1]:
        res_m2_V4[i] = 1
        
m2_V5 = m2['V5']
res_m2_V5 = [0] * 100
for i in range(len(m2_V1)):
    if limits_V5[0] <= m2_V5[i] <= limits_V5[1]:
        res_m2_V5[i] = 1

# %%
m3_V1 = m3['V1']
res_m3_V1 = [0] * 100
for i in range(len(m3_V1)):
    if limits_V1[0] <= m3_V1[i] <= limits_V1[1]:
        res_m3_V1[i] = 1

m3_V2 = m3['V2']
res_m3_V2 = [0] * 100
for i in range(len(m3_V1)):
    if limits_V2[0] <= m3_V2[i] <= limits_V2[1]:
        res_m3_V2[i] = 1

m3_V3 = m3['V3']
res_m3_V3 = [0] * 100
for i in range(len(m3_V3)):
    if limits_V3[0] <= m3_V3[i] <= limits_V3[1]:
        res_m3_V3[i] = 1
        
m3_V4 = m3['V4']
res_m3_V4 = [0] * 100
for i in range(len(m3_V4)):
    if limits_V4[0] <= m3_V4[i] <= limits_V4[1]:
        res_m3_V4[i] = 1
        
m3_V5 = m3['V5']
res_m3_V5 = [0] * 100
for i in range(len(m3_V1)):
    if limits_V5[0] <= m3_V5[i] <= limits_V5[1]:
        res_m3_V5[i] = 1

# %% [markdown]
# # Q2

# %%
cnt_m1V1 = 0
for i in range(len(res_m1_V1)):
    if res_m1_V1[i] == 0:
        cnt_m1V1 += 1
fail_per_m1V1 = cnt_m1V1 / 100
print('Failure percentage of m1V1:', fail_per_m1V1)

cnt_m1V2 = 0
for i in range(len(res_m1_V2)):
    if res_m1_V2[i] == 0:
        cnt_m1V2 += 1
fail_per_m1V2 = cnt_m1V2 / 100
print('Failure percentage of m1V2:', fail_per_m1V2)

cnt_m1V3 = 0
for i in range(len(res_m1_V3)):
    if res_m1_V3[i] == 0:
        cnt_m1V3 += 1
fail_per_m1V3 = cnt_m1V3 / 100
print('Failure percentage of m1V3:', fail_per_m1V3)

cnt_m1V4 = 0
for i in range(len(res_m1_V4)):
    if res_m1_V4[i] == 0:
        cnt_m1V4 += 1
fail_per_m1V4 = cnt_m1V4 / 100
print('Failure percentage of m1V4:', fail_per_m1V4)

cnt_m1V5 = 0
for i in range(len(res_m1_V5)):
    if res_m1_V5[i] == 0:
        cnt_m1V5 += 1
fail_per_m1V5 = cnt_m1V5 / 100
print('Failure percentage of m1V5:', fail_per_m1V5)
# Out:
# Failure percentage of m1V1: 0.11
# Failure percentage of m1V2: 0.28
# Failure percentage of m1V3: 0.0
# Failure percentage of m1V4: 0.65
# Failure percentage of m1V5: 0.28

# %%
cnt_m2V1 = 0
for i in range(len(res_m2_V1)):
    if res_m2_V1[i] == 0:
        cnt_m2V1 += 1
fail_per_m2V1 = cnt_m2V1 / 100
print('Failure percentage of m2V1:', fail_per_m2V1)

cnt_m2V2 = 0
for i in range(len(res_m2_V2)):
    if res_m2_V2[i] == 0:
        cnt_m2V2 += 1
fail_per_m2V2 = cnt_m2V2 / 100
print('Failure percentage of m2V2:', fail_per_m2V2)

cnt_m2V3 = 0
for i in range(len(res_m2_V3)):
    if res_m2_V3[i] == 0:
        cnt_m2V3 += 1
fail_per_m2V3 = cnt_m2V3 / 100
print('Failure percentage of m2V3:', fail_per_m2V3)

cnt_m2V4 = 0
for i in range(len(res_m2_V4)):
    if res_m2_V4[i] == 0:
        cnt_m2V4 += 1
fail_per_m2V4 = cnt_m2V4 / 100
print('Failure percentage of m2V4:', fail_per_m2V4)

cnt_m2V5 = 0
for i in range(len(res_m2_V5)):
    if res_m2_V5[i] == 0:
        cnt_m2V5 += 1
fail_per_m2V5 = cnt_m2V5 / 100
print('Failure percentage of m2V5:', fail_per_m2V5)
# Out:
# Failure percentage of m2V1: 0.01
# Failure percentage of m2V2: 0.02
# Failure percentage of m2V3: 0.0
# Failure percentage of m2V4: 0.42
# Failure percentage of m2V5: 0.06

# %%
cnt_m3V1 = 0
for i in range(len(res_m3_V1)):
    if res_m3_V1[i] == 0:
        cnt_m3V1 += 1
fail_per_m3V1 = cnt_m3V1 / 100
print('Failure percentage of m3V1:', fail_per_m3V1)

cnt_m3V2 = 0
for i in range(len(res_m3_V2)):
    if res_m3_V2[i] == 0:
        cnt_m3V2 += 1
fail_per_m3V2 = cnt_m3V2 / 100
print('Failure percentage of m3V2:', fail_per_m3V2)

cnt_m3V3 = 0
for i in range(len(res_m3_V3)):
    if res_m3_V3[i] == 0:
        cnt_m3V3 += 1
fail_per_m3V3 = cnt_m3V3 / 100
print('Failure percentage of m3V3:', fail_per_m3V3)

cnt_m3V4 = 0
for i in range(len(res_m3_V4)):
    if res_m3_V4[i] == 0:
        cnt_m3V4 += 1
fail_per_m3V4 = cnt_m3V4 / 100
print('Failure percentage of m3V4:', fail_per_m3V4)

cnt_m3V5 = 0
for i in range(len(res_m3_V5)):
    if res_m3_V5[i] == 0:
        cnt_m3V5 += 1
fail_per_m3V5 = cnt_m3V5 / 100
print('Failure percentage of m3V5:', fail_per_m3V5)
# Out:
# Failure percentage of m3V1: 0.0
# Failure percentage of m3V2: 0.66
# Failure percentage of m3V3: 0.0
# Failure percentage of m3V4: 0.09
# Failure percentage of m3V5: 0.05

# %% [markdown]
# # Q3 Q4

# %%
import numpy as np
V1_fail_arr = [fail_per_m1V1, fail_per_m2V1, fail_per_m3V1]
V1_mean = np.mean(V1_fail_arr)
V1_var = np.var(V1_fail_arr)
V1_std = np.std(V1_fail_arr,ddof=1)
print("V1 mean value", V1_mean)
print("V1 variance", V1_var)
print("V1 standard deviation", V1_std)
# Out:
# V1 mean value 0.04
# V1 variance 0.002466666666666667
# V1 standard deviation 0.0608276253029822

# %%
V2_fail_arr = [fail_per_m1V2, fail_per_m2V2, fail_per_m3V2]
V2_mean = np.mean(V2_fail_arr)
V2_var = np.var(V2_fail_arr)
V2_std = np.std(V2_fail_arr,ddof=1)
print("V2 mean value", V2_mean)
print("V2 variance", V2_var)
print("V2 standard deviation", V2_std)
# Out:
# V2 mean value 0.32
# V2 variance 0.06906666666666668
# V2 standard deviation 0.3218695387886216

# %%
V3_fail_arr = [fail_per_m1V3, fail_per_m2V3, fail_per_m3V3]
V3_mean = np.mean(V3_fail_arr)
V3_var = np.var(V3_fail_arr)
V3_std = np.std(V3_fail_arr,ddof=1)
print("V3 mean value", V3_mean)
print("V3 variance", V3_var)
print("V3 standard deviation", V3_std)
# Out:
# V3 mean value 0.0
# V3 variance 0.0
# V3 standard deviation 0.0

# %%
V4_fail_arr = [fail_per_m1V4, fail_per_m2V4, fail_per_m3V4]
V4_mean = np.mean(V4_fail_arr)
V4_var = np.var(V4_fail_arr)
V4_std = np.std(V4_fail_arr,ddof=1)
print("V4 mean value", V4_mean)
print("V4 variance", V4_var)
print("V4 standard deviation", V4_std)
# Out:
# V4 mean value 0.3866666666666667
# V4 variance 0.052822222222222236
# V4 standard deviation 0.2814841617806113

# %%
V5_fail_arr = [fail_per_m1V5, fail_per_m2V5, fail_per_m3V5]
V5_mean = np.mean(V5_fail_arr)
V5_var = np.var(V5_fail_arr)
V5_std = np.std(V5_fail_arr,ddof=1)
print("V5 mean value", V5_mean)
print("V5 variance", V5_var)
print("V5 standard deviation", V5_std)
# Out:
# V5 mean value 0.13
# V5 variance 0.01126666666666667
# V5 standard deviation 0.13000000000000003

# %% [markdown]
# # Answer:
# After comparing the variance and standard deviation of each parameter:
#
# Q3:
# We found that V4 has the largest variance and standard deviation, so V4 varies the most between the three machines.
#
# Q4:
# We found that V3 has the smallest variance and standard deviation, so V3 varies the least between the three machines

# %% [markdown]
# # Q5
# Answer:
# R statistics has a simulation function, which can simulate data based on existing data models. This will fit the model using the "known" overall relationship, and then simulate new data based on the model. These fitting objects can consider random and fixed effects and correlation (including autocorrelation of time series). Also, we could apply machine learing models such as GMM, which is a generative modeling technique that can generate comprehensive data that closely fits the data distribution.
